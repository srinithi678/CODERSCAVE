# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize,sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("/content/emails1.csv")

# %%
data.head()
# Out:
#                                                 text spam Unnamed: 2  \
# 0  Subject: naturally irresistible your corporate...    1        NaN
# 1  Subject: the stock trading gunslinger  fanny i...    1        NaN
# 2  Subject: unbelievable new homes made easy  im ...    1        NaN
# 3  Subject: 4 color printing special  request add...    1        NaN
# 4  Subject: do not have money , get software cds ...    1        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 100 Unnamed: 101 Unnamed: 102 Unnamed: 103  \
# 0        NaN  ...          NaN          NaN          NaN          NaN
# 1        NaN  ...          NaN          NaN          NaN          NaN
# 2        NaN  ...          NaN          NaN          NaN          NaN
# 3        NaN  ...          NaN          NaN          NaN          NaN
# 4        NaN  ...          NaN          NaN          NaN          NaN
#
#   Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 109
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 110 columns]

# %%
df.describe()
# Out:
#                  id
# count    225.000000
# mean   17315.831111
# std     6788.533806
# min       40.000000
# 25%    20042.000000
# 50%    20112.000000
# 75%    20170.000000
# max    20233.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 225 non-null    int64
#  1   person_name        225 non-null    object
#  2   nine_box_category  225 non-null    object
#  3   feedback           225 non-null    object
#  4   updated            225 non-null    bool
#  5   reviewed           225 non-null    bool
# dtypes: bool(2), int64(1), object(3)
# memory usage: 7.6+ KB

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data['text']=data['text'].apply(word_tokenize)

# %%
data
# Out:
#                                                    text spam Unnamed: 2  \
# 0     [Subject, :, naturally, irresistible, your, co...    1        NaN
# 1     [Subject, :, the, stock, trading, gunslinger, ...    1        NaN
# 2     [Subject, :, unbelievable, new, homes, made, e...    1        NaN
# 3     [Subject, :, 4, color, printing, special, requ...    1        NaN
# 4     [Subject, :, do, not, have, money, ,, get, sof...    1        NaN
# ...                                                 ...  ...        ...
# 5725  [Subject, :, re, :, research, and, development...    0        NaN
# 5726  [Subject, :, re, :, receipts, from, visit, jim...    0        NaN
# 5727  [Subject, :, re, :, enron, case, study, update...    0        NaN
# 5728  [Subject, :, re, :, interest, david, ,, please...    0        NaN
# 5729  [Subject, :, news, :, aurora, 5, ., 2, update,...    0        NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 5725        NaN        NaN        NaN        NaN        NaN        NaN
# 5726        NaN        NaN        NaN        NaN        NaN        NaN
# 5727        NaN        NaN        NaN        NaN        NaN        NaN
# 5728        NaN        NaN        NaN        NaN        NaN        NaN
# 5729        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 9  ... Unnamed: 100 Unnamed: 101 Unnamed: 102 Unnamed: 103  \
# 0           NaN  ...          NaN          NaN          NaN          NaN
# 1           NaN  ...          NaN          NaN          NaN          NaN
# 2           NaN  ...          NaN          NaN          NaN          NaN
# 3           NaN  ...          NaN          NaN          NaN          NaN
# 4           NaN  ...          NaN          NaN          NaN          NaN
# ...         ...  ...          ...          ...          ...          ...
# 5725        NaN  ...          NaN          NaN          NaN          NaN
# 5726        NaN  ...          NaN          NaN          NaN          NaN
# 5727        NaN  ...          NaN          NaN          NaN          NaN
# 5728        NaN  ...          NaN          NaN          NaN          NaN
# 5729        NaN  ...          NaN          NaN          NaN          NaN
#
#      Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 5725          NaN          NaN          NaN          NaN          NaN
# 5726          NaN          NaN          NaN          NaN          NaN
# 5727          NaN          NaN          NaN          NaN          NaN
# 5728          NaN          NaN          NaN          NaN          NaN
# 5729          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 109
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 5725          NaN
# 5726          NaN
# 5727          NaN
# 5728          NaN
# 5729          NaN
#
# [5730 rows x 110 columns]

# %%
data['text']=data['text'].apply(lambda x: [item for item in x if item.isalpha()])

# %%
data['text']=data['text'].apply(lambda x: [item.lower() for item in x])

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data['text']=data['text'].apply(lambda x: [item for item in x if item not in stop_words])

# %%
data.head()
# Out:
#                                                 text spam Unnamed: 2  \
# 0  [subject, naturally, irresistible, corporate, ...    1        NaN
# 1  [subject, stock, trading, gunslinger, fanny, m...    1        NaN
# 2  [subject, unbelievable, new, homes, made, easy...    1        NaN
# 3  [subject, color, printing, special, request, a...    1        NaN
# 4  [subject, money, get, software, cds, software,...    1        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 100 Unnamed: 101 Unnamed: 102 Unnamed: 103  \
# 0        NaN  ...          NaN          NaN          NaN          NaN
# 1        NaN  ...          NaN          NaN          NaN          NaN
# 2        NaN  ...          NaN          NaN          NaN          NaN
# 3        NaN  ...          NaN          NaN          NaN          NaN
# 4        NaN  ...          NaN          NaN          NaN          NaN
#
#   Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 109
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 110 columns]

# %%
data['text'] = data['text'].apply(lambda x: " ".join(x))

# %%
train_text = data.text[:3500]
test_text = data.text[3500:]
train_spam = data.spam[:3500]
test_spam = data.spam[3500:]

# %%
data.head()
# Out:
#                                                 text spam Unnamed: 2  \
# 0  subject naturally irresistible corporate ident...    1        NaN
# 1  subject stock trading gunslinger fanny merrill...    1        NaN
# 2  subject unbelievable new homes made easy im wa...    1        NaN
# 3  subject color printing special request additio...    1        NaN
# 4  subject money get software cds software compat...    1        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 100 Unnamed: 101 Unnamed: 102 Unnamed: 103  \
# 0        NaN  ...          NaN          NaN          NaN          NaN
# 1        NaN  ...          NaN          NaN          NaN          NaN
# 2        NaN  ...          NaN          NaN          NaN          NaN
# 3        NaN  ...          NaN          NaN          NaN          NaN
# 4        NaN  ...          NaN          NaN          NaN          NaN
#
#   Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 109
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 110 columns]

# %%
cv = CountVectorizer(min_df=0, max_df=1, binary = False, ngram_range = (1,3))

# %%
cv_train_text = cv.fit_transform(train_text)
cv_test_text = cv.transform(test_text)
